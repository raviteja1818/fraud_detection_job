# %% [markdown]
# ## UNDERSTANDING THE DATA

# %%
import pandas as pd

# %%
train_path = "../data/NqndMEyZakuimmFI.csv"
train_df = pd.read_csv(train_path)

# %%
train_info = train_df.info()
train_sample = train_df.sample(5, random_state=42)
train_distribution = train_df['fraudulent'].value_counts(normalize=True)

train_df.shape, train_info, train_sample, train_distribution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14304 entries, 0 to 14303
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               14304 non-null  int64
#  1   title                14304 non-null  object
#  2   location             14024 non-null  object
#  3   department           5029 non-null   object
#  4   salary_range         2283 non-null   object
#  5   company_profile      11632 non-null  object
#  6   description          14303 non-null  object
#  7   requirements         12172 non-null  object
#  8   benefits             8501 non-null   object
#  9   telecommuting        14304 non-null  int64
#  10  has_company_logo     14304 non-null  int64
#  11  has_questions        14304 non-null  int64
#  12  employment_type      11547 non-null  object
#  13  required_experience  8629 non-null   object
#  14  required_education   7805 non-null   object
#  15  industry             10378 non-null  object
#  16  function             9135 non-null   object
#  17  fraudulent           14304 non-null  int64
# dtypes: int64(5), object(13)
# memory usage: 2.0+ MB
# ((14304, 18),
#  None,
#        job_id                                             title  \
#  9844   16792                    Senior Developer Ruby on Rails
#  4509   12602             Beauty & Fragrance consultants needed
#  1010   14785                 IT Consultant / Software Enginner
#  7495   14229  SQL Server DBA Job opportunity at Barrington, IL
#  5173    6118                                      Web Designer
#
#                  location            department  salary_range  \
#  9844      PL, WP, Poznań                   NaN           NaN
#  4509          GB, , Fife                   NaN           NaN
#  1010       GR, I, Athens  Consulting Workforce           NaN
#  7495  US, IL, Barrington                   NaN  90000-110000
#  5173            HU, BU,                    NaN           NaN
#
#                                          company_profile  \
#  9844  Hello, we are Netguru and we love web developm...
#  4509  Established on the principles that full time e...
#  1010  improvIT - this is our mission; to help insura...
#  7495  We are an innovative personnel-sourcing firm w...
#  5173                                                NaN
#
#                                              description  \
#  9844  Hi! We are Netguru! We design, create, impleme...
#  4509  Luxury beauty &amp; fragrance consultants need...
#  1010  IT Consultant, as a member of a larger team, w...
#  7495  Position :  SQL Server DBAJob Location : Locat...
#  5173  We’re looking for a web designer with a passio...
#
#                                             requirements  \
#  9844  Apply if you:Have hands-on knowledge of: - Rub...
#  4509                                                NaN
#  1010  - Very good educational background in IT or in...
#  7495  Position :  SQL Server DBAJob Location : Locat...
#  5173  What skills are we looking for?English-speakin...
#
#                                                 benefits  telecommuting  \
#  9844  We want you to come on our borad to:give you a...              0
#  4509                                                NaN              0
#  1010  We offer:Competitive compensation packagesComp...              0
#  7495                                                NaN              0
#  5173                                                NaN              1
#
#        has_company_logo  has_questions employment_type required_experience  \
#  9844                 1              1             NaN                 NaN
#  4509                 1              0             NaN                 NaN
#  1010                 1              0       Full-time           Associate
#  7495                 0              0       Full-time    Mid-Senior level
#  5173                 1              1             NaN                 NaN
#
#       required_education                             industry        function  \
#  9844                NaN                                  NaN             NaN
#  4509                NaN                                  NaN             NaN
#  1010  Bachelor's Degree  Information Technology and Services      Consulting
#  7495  Bachelor's Degree  Information Technology and Services  Administrative
#  5173                NaN                                  NaN             NaN
#
#        fraudulent
#  9844           0
#  4509           0
#  1010           0
#  7495           0
#  5173           0  ,
#  fraudulent
#  0    0.951552
#  1    0.048448
#  Name: proportion, dtype: float64)

# %% [markdown]
# ### TRAINING AND STREAMLING THE MODEL PROCESSESING

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# %%
train_df.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'fraudulent'],
#       dtype='object')

# %%
target = 'fraudulent'
text_cols = ['title', 'company_profile', 'description', 'requirements', 'benefits']
cat_cols = ['employment_type', 'required_experience', 'required_education', 'industry', 'function']
num_cols = ['telecommuting', 'has_company_logo', 'has_questions']
selected_cols = text_cols + cat_cols + num_cols + [target]

df = train_df[selected_cols].copy()
df.head()
# Out:
#                              title  \
# 0   Contact Center Representatives
# 1      Customer Service Associate
# 2           Automated Test Analyst
# 3  Inside Sales Professional-Omaha
# 4    Content Marketing/SEO Manager
#
#                                      company_profile  \
# 0  Tidewater Finance Co. was established in 1992 ...
# 1  Novitex Enterprise Solutions, formerly Pitney ...
# 2  SilverStripe CMS &amp; Framework is an open so...
# 3  ABC Supply Co., Inc. is the nation’s largest w...
# 4  MeUndies is a lifestyle brand that is transfor...
#
#                                          description  \
# 0  Tidewater Finance Company, located in Virginia...
# 1  The Customer Service Associate will be based i...
# 2  We are looking for a dedicated and passionate ...
# 3  As a Sales Representative, you will provide as...
# 4  MeUndies is a lifestyle brand that is transfor...
#
#                                         requirements  \
# 0  The position requires the following qualificat...
# 1  QualificationsMinimum of 1 year customer servi...
# 2                                                NaN
# 3  As a Sales Representative, you must have the a...
# 4  REQUIREMENTS/QUALIFICATIONS/PERSONAL ATTRIBUTE...
#
#                                             benefits employment_type  \
# 0  Our company offers a competitive salary plus B...       Full-time
# 1                                                NaN       Full-time
# 2                                                NaN       Full-time
# 3  Your benefits package as a Sales Representativ...       Full-time
# 4  WHY MEUNDIES?We're a fast-growing, VC-backed c...       Full-time
#
#   required_experience         required_education  \
# 0         Entry level                Unspecified
# 1         Entry level  High School or equivalent
# 2    Mid-Senior level                        NaN
# 3                 NaN                        NaN
# 4    Mid-Senior level          Bachelor's Degree
#
#                               industry          function  telecommuting  \
# 0                   Financial Services  Customer Service              0
# 1                   Telecommunications  Customer Service              0
# 2  Information Technology and Services               NaN              0
# 3                   Building Materials             Sales              0
# 4                             Internet         Marketing              0
#
#    has_company_logo  has_questions  fraudulent
# 0                 1              0           0
# 1                 1              0           0
# 2                 1              1           0
# 3                 1              0           0
# 4                 1              0           0

# %%
df['text'] = df[text_cols].fillna('').agg(' '.join, axis=1)

# %%
X = df[['text']+ cat_cols+ num_cols]
y = df[target]

# %%
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
class_weights_dict = {0: class_weights[0], 1: class_weights[1]}

# %%
class_weights
# Out:
# array([ 0.52545735, 10.32034632])

# %%
text_transformer = Pipeline(steps=[
    ('tfdif', TfidfVectorizer(max_features=5000, stop_words='english'))
])

# %%
cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer(transformers=[
    ('text', text_transformer, 'text'),
    ('cat', cat_transformer, cat_cols)
], remainder='passthrough')

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('text',
#                                  Pipeline(steps=[('tfdif',
#                                                   TfidfVectorizer(max_features=5000,
#                                                                   stop_words='english'))]),
#                                  'text'),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['employment_type', 'required_experience',
#                                   'required_education', 'industry',
#                                   'function'])])

# %%
pipeline = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('clf', LogisticRegression(max_iter=200, class_weight=class_weights_dict))
])

# %%
pipeline
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('text',
#                                                   Pipeline(steps=[('tfdif',
#                                                                    TfidfVectorizer(max_features=5000,
#                                                                                    stop_words='english'))]),
#                                                   'text'),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['employment_type',
#                                                    'required_experience',
#                                                    'required_education',
#                                                    'industry', 'function'])])),
#                 ('clf',
#                  LogisticRegression(class_weight={0: np.float64(0.5254573506722504),
#                                                   1: np.float64(10.32034632034632)},
#                                     max_iter=200))])

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('text',
#                                                   Pipeline(steps=[('tfdif',
#                                                                    TfidfVectorizer(max_features=5000,
#                                                                                    stop_words='english'))]),
#                                                   'text'),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['employment_type',
#                                                    'required_experience',
#                                                    'required_education',
#                                                    'industry', 'function'])])),
#                 ('clf',
#                  LogisticRegression(class_weight={0: np.float64(0.5254573506722504),
#                                                   1: np.float64(10.32034632034632)},
#                                     max_iter=200))])

# %%
y_pred = pipeline.predict(X_val)
f1 = f1_score(y_val, y_pred)
report = classification_report(y_val, y_pred, output_dict=True)

f1, report
# Out:
# (0.6684636118598383,
#  {'0': {'precision': 0.9942944085203499,
#    'recall': 0.9603232916972814,
#    'f1-score': 0.9770136423098487,
#    'support': 2722.0},
#   '1': {'precision': 0.5344827586206896,
#    'recall': 0.8920863309352518,
#    'f1-score': 0.6684636118598383,
#    'support': 139.0},
#   'accuracy': 0.9570080391471514,
#   'macro avg': {'precision': 0.7643885835705198,
#    'recall': 0.9262048113162666,
#    'f1-score': 0.8227386270848435,
#    'support': 2861.0},
#   'weighted avg': {'precision': 0.9719547303183043,
#    'recall': 0.9570080391471514,
#    'f1-score': 0.9620229208024906,
#    'support': 2861.0}})

# %%
import joblib
import os

# %%
model_dir = "../model"
os.makedirs(model_dir, exist_ok=True)

# %%
model_path = os.path.join(model_dir, "fraud_detector_pipeline.pkl")
joblib.dump(pipeline, model_path)
# Out:
# ['../model\\fraud_detector_pipeline.pkl']

# %%
model_path
# Out:
# '../model\\fraud_detector_pipeline.pkl'
